# %%
import pandas as pd

# %%
df = pd.read_csv("./fraudTrain.csv", index_col=0)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      lat      long  \
# 0                561 Perry Cove  Moravian Falls  ...  36.0788  -81.1781
# ...

# %%
from datetime import date

df['dob'] = pd.to_datetime(df['dob'])
today = pd.to_datetime(date.today())
df['age'] = (today - df['dob']).dt.days // 365

# %%
date_time = pd.to_datetime(df['trans_date_trans_time'], format='%Y-%m-%d %H:%M:%S')

df['day_of_week'] = date_time.dt.day_of_week
df['day_of_month'] = date_time.dt.day
df['time_of_day'] = date_time.dt.hour
df['month'] = date_time.dt.month

# %%
df.drop(columns=["first","last","gender","trans_num","unix_time","merch_lat","merch_long",'trans_date_trans_time',"cc_num","lat","long","city_pop","zip","dob"] , inplace=True)

# %%
df.head()
# Out:
#                              merchant       category     amt  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# 2                fraud_Lind-Buckridge  entertainment  220.11
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00
# 4                 fraud_Keeling-Crist       misc_pos   41.96
#
#                          street            city state  \
# 0                561 Perry Cove  Moravian Falls    NC
# 1  43039 Riley Greens Suite 393          Orient    WA
# 2      594 White Dale Suite 530      Malad City    ID
# 3   9443 Cynthia Court Apt. 038         Boulder    MT
# 4              408 Bradley Rest        Doe Hill    VA
#
#                                  job  is_fraud  age  day_of_week  \
# 0          Psychologist, counselling         0   38            1
# 1  Special educational needs teacher         0   47            1
# 2        Nature conservation officer         0   64            1
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from category_encoders import JamesSteinEncoder
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

one_hot_encodable = ["category","state"]
target_encodable = ["merchant","city","street","job"]


preprocessor = ColumnTransformer(
    transformers=[
        ('num', JamesSteinEncoder(), target_encodable),
        ('cat', OneHotEncoder(), one_hot_encodable)
    ],
    remainder='passthrough'  # Options: 'drop' (default) or 'passthrough'
)
